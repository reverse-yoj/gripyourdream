# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/russia_losses_equipment.csv")

# %%
df
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80    516               49    4
# 1    2022-02-26    3        27          26   146    706               49    4
# 2    2022-02-27    4        27          26   150    706               50    4
# 3    2022-02-28    5        29          29   150    816               74   21
# 4    2022-03-01    6        29          29   198    846               77   24
# ..          ...  ...       ...         ...   ...    ...              ...  ...
# 642  2023-11-29  644       323         324  5538  10312             7908  910
# 643  2023-11-30  645       323         324  5551  10340             7909  910
# 644  2023-12-01  646       323         324  5564  10372             7931  912
# 645  2023-12-02  647       323         324  5571  10385             7941  913
# 646  2023-12-03  648       323         324  5575  10396             7949  913
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       647 non-null    object
#  1   day                        647 non-null    int64
#  2   aircraft                   647 non-null    int64
#  3   helicopter                 647 non-null    int64
#  4   tank                       647 non-null    int64
#  5   APC                        647 non-null    int64
#  6   field artillery            647 non-null    int64
#  7   MRL                        647 non-null    int64
#  8   military auto              65 non-null     float64
#  9   fuel tank                  65 non-null     float64
#  10  drone                      647 non-null    int64
#  11  naval ship                 647 non-null    int64
#  12  anti-aircraft warfare      647 non-null    int64
# ...

# %%
df.shape
# Out:
# (647, 19)

# %%
df.isnull()
# Out:
#       date    day  aircraft  helicopter   tank    APC  field artillery    MRL  \
# 0    False  False     False       False  False  False            False  False
# 1    False  False     False       False  False  False            False  False
# 2    False  False     False       False  False  False            False  False
# 3    False  False     False       False  False  False            False  False
# 4    False  False     False       False  False  False            False  False
# ..     ...    ...       ...         ...    ...    ...              ...    ...
# 642  False  False     False       False  False  False            False  False
# 643  False  False     False       False  False  False            False  False
# 644  False  False     False       False  False  False            False  False
# 645  False  False     False       False  False  False            False  False
# 646  False  False     False       False  False  False            False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                582
# fuel tank                    582
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment             19
# mobile SRBM system           611
# greatest losses direction    444
# vehicles and fuel tanks       65
# cruise missiles               65
# submarines                   566
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-16-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
df.isnull().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                  0
# fuel tank                      0
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment              0
# mobile SRBM system             0
# greatest losses direction    444
# vehicles and fuel tanks        0
# cruise missiles                0
# submarines                     0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-20-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                  0
# fuel tank                      0
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment              0
# mobile SRBM system             0
# greatest losses direction    444
# vehicles and fuel tanks        0
# cruise missiles                0
# submarines                     0
# dtype: int64

# %%
df.dropna(subset=['greatest losses direction'], inplace=True)

# %%
df.isnull().sum()
# Out:
# date                         0
# day                          0
# aircraft                     0
# helicopter                   0
# tank                         0
# APC                          0
# field artillery              0
# MRL                          0
# military auto                0
# fuel tank                    0
# drone                        0
# naval ship                   0
# anti-aircraft warfare        0
# special equipment            0
# mobile SRBM system           0
# greatest losses direction    0
# vehicles and fuel tanks      0
# cruise missiles              0
# submarines                   0
# dtype: int64

# %%
df.describe()
# Out:
#               day    aircraft  helicopter         tank          APC  \
# count  203.000000  203.000000  203.000000   203.000000   203.000000
# mean   166.788177  233.029557  201.822660  1892.960591  4175.906404
# std     66.424300   27.782734   32.763903   569.546448   964.554540
# min     61.000000  181.000000  154.000000   884.000000  2258.000000
# 25%    111.500000  213.000000  179.000000  1437.000000  3515.500000
# 50%    162.000000  223.000000  191.000000  1789.000000  4026.000000
# 75%    215.500000  260.500000  224.000000  2298.000000  4869.000000
# max    313.000000  283.000000  269.000000  3031.000000  6093.000000
#
#        field artillery         MRL  military auto   fuel tank        drone  \
# count       203.000000  203.000000     203.000000  203.000000   203.000000
# mean       1060.600985  275.788177    1065.605987   69.520424   830.891626
# std         447.642553   71.940841     104.265813    1.133604   378.977556
# ...

# %%
x = df[["day"]]
y = df[["aircraft","helicopter","fuel tank","field artillery","special equipment"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=
0.8)

# %%
from sklearn.linear_model import LinearRegression

# %%
kk = LinearRegression()

# %%
reg = kk.fit(x_train,y_train)

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([[ 235.84437885,  205.14554512,   69.48875559, 1105.92446947,
#           96.06444214],
#        [ 210.69448609,  175.59107558,   69.7776304 ,  700.29812556,
#           56.71725165],
#        [ 232.13373893,  200.78504962,   69.53137646, 1046.07795971,
#           90.25911896],
#        [ 218.11576592,  184.31206659,   69.69238865,  819.99114508,
#           68.32789803],
#        [ 242.85336536,  213.38203664,   69.40824949, 1218.96787678,
#          107.03005261],
#        [ 270.47701806,  245.84350318,   69.09096075, 1664.49189386,
#          150.24745856],
#        [ 195.43963311,  157.66459405,   69.95284956,  454.26247435,
#           32.85092299],
#        [ 250.68693851,  222.58752715,   69.31827209, 1345.31050849,
#          119.28573489],
#        [ 206.57155285,  170.74608057,   69.82498693,  633.80200361,
#           50.26689255],
#        [ 247.80088524,  219.19603064,   69.35142166, 1298.76322313,
#          114.77048352],
# ...

# %%
y_test
# Out:
#      aircraft  helicopter  fuel tank  field artillery  special equipment
# 171       233         195  69.323077              985               92.0
# 110       213         179  69.323077              722               55.0
# 162       223         191  69.323077              955               85.0
# 128       217         187  69.323077              801               64.0
# 188       234         205  69.323077             1115              104.0
# 255       277         260  69.323077             1782              157.0
# 73        199         158  69.323077              513               41.0
# 207       252         217  69.323077             1323              125.0
# 100       210         175  69.323077              686               53.0
# 200       244         213  69.323077             1279              117.0
# 307       283         268  69.323077             2004              179.0
# 185       234         203  69.323077             1060              101.0
# ...

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score (y_test,y_pred))
# Out:
# 0.7880439329400243

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 1160.0122466294436

# %%
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 34.058952518089036

# %%
reg.predict([[5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[166.57910043, 123.74962901,  70.28434525, -11.21037931,
#         -12.30159069]])

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df= pd.read_csv("/russia_losses_equipment.csv")
df
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80    516               49    4
# 1    2022-02-26    3        27          26   146    706               49    4
# 2    2022-02-27    4        27          26   150    706               50    4
# 3    2022-02-28    5        29          29   150    816               74   21
# 4    2022-03-01    6        29          29   198    846               77   24
# ..          ...  ...       ...         ...   ...    ...              ...  ...
# 642  2023-11-29  644       323         324  5538  10312             7908  910
# 643  2023-11-30  645       323         324  5551  10340             7909  910
# 644  2023-12-01  646       323         324  5564  10372             7931  912
# 645  2023-12-02  647       323         324  5571  10385             7941  913
# 646  2023-12-03  648       323         324  5575  10396             7949  913
#
# ...

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <ipython-input-48-2d3646dd07cf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)
# <Axes: >

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-71-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# date                           0
# day                            0
# aircraft                       0
# helicopter                     0
# tank                           0
# APC                            0
# field artillery                0
# MRL                            0
# military auto                  0
# fuel tank                      0
# drone                          0
# naval ship                     0
# anti-aircraft warfare          0
# special equipment              0
# mobile SRBM system             0
# greatest losses direction    444
# vehicles and fuel tanks        0
# cruise missiles                0
# submarines                     0
# dtype: int64

# %%
df.dropna(subset=['greatest losses direction'], inplace=True)

# %%
df.isnull().sum()
# Out:
# date                         0
# day                          0
# aircraft                     0
# helicopter                   0
# tank                         0
# APC                          0
# field artillery              0
# MRL                          0
# military auto                0
# fuel tank                    0
# drone                        0
# naval ship                   0
# anti-aircraft warfare        0
# special equipment            0
# mobile SRBM system           0
# greatest losses direction    0
# vehicles and fuel tanks      0
# cruise missiles              0
# submarines                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 59 to 311
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       203 non-null    object
#  1   day                        203 non-null    int64
#  2   aircraft                   203 non-null    int64
#  3   helicopter                 203 non-null    int64
#  4   tank                       203 non-null    int64
#  5   APC                        203 non-null    int64
#  6   field artillery            203 non-null    int64
#  7   MRL                        203 non-null    int64
#  8   military auto              203 non-null    float64
#  9   fuel tank                  203 non-null    float64
#  10  drone                      203 non-null    int64
#  11  naval ship                 203 non-null    int64
#  12  anti-aircraft warfare      203 non-null    int64
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-ea8415b8a3ee> in <cell line: 1>()
# ----> 1 df.describe()
#
# AttributeError: 'LogisticRegression' object has no attribute 'describe'

# %%
x=df[["day","aircraft"]]
y=df[["fuel tank"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-de6266f4fb0e> in <cell line: 1>()
# ----> 1 x=df[["day","aircraft"]]
#       2 y=df[["fuel tank"]]
#
# TypeError: 'LogisticRegression' object is not subscriptable

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=200)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-b7a8c64777c1> in <cell line: 1>()
# ----> 1 model.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined
